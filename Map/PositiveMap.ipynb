# %%
import logging
import os
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim
# from googlesearch import search
logging.getLogger('scrapy').propagate = False

# %% [markdown]
# ### Scrap the addresses

# %%
members = pd.read_table("Founding members - Founding Members.csv", sep=",")
members['ADDRESS']= ""

# %%
members = members[0:103]

# %%
# URL list
url_list = "https://www.google.com/search?q=" + members.COMPANIES + " address"
url_list.head(10)
# Out:
# 0     https://www.google.com/search?q=Rerooted address
# 1    https://www.google.com/search?q=Think Ocean ad...
# 2         https://www.google.com/search?q=Olio address
# 3        https://www.google.com/search?q=Aduna address
# 4    https://www.google.com/search?q=Groots Urban F...
# 5    https://www.google.com/search?q=City Farms add...
# 6     https://www.google.com/search?q=Grounded address
# 7        https://www.google.com/search?q=Ivalo address
# 8    https://www.google.com/search?q=Sea 2 see address
# 9    https://www.google.com/search?q=Films for the ...
# Name: COMPANIES, dtype: object

# %%
i = 0
for url in url_list:
    getpage= requests.get(url).text
    soup = BeautifulSoup(getpage, 'html.parser')
    if len(soup.findAll("div", {"BNeawe iBp4i AP7Wnd"}))>1:
        mydivs = soup.findAll("div", {"BNeawe iBp4i AP7Wnd"})[0]
        output = mydivs.string
    elif len(soup.findAll("div", {"BNeawe iBp4i AP7Wnd"}))==1:
        mydivs = soup.findAll("div", {"BNeawe iBp4i AP7Wnd"})
        output = mydivs.string
    else:
        output = "no address found"
    print(output)
    members['ADDRESS'][i] = output
    i+=1
# Out:
# 11 Burke Rd, Totnes TQ9 5XL, Royaume-Uni
# no address found
# J:\Code\conda\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# no address found
# no address found
# Ronda Indústria, 6, 08210 Barberà del Vallès, Barcelona, Espagne
# no address found
# From cffi callback <function _verify_callback at 0x000002762F719CA8>:
# Traceback (most recent call last):
#   File "J:\Code\conda\lib\site-packages\OpenSSL\SSL.py", line 311, in wrapper
#     @wraps(callback)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# J:\Code\conda\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     484             try:
# --> 485                 cnx.do_handshake()
#     486             except OpenSSL.SSL.WantReadError:
#
# J:\Code\conda\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1933         result = _lib.SSL_do_handshake(self._ssl)
# -> 1934         self._raise_ssl_error(self._ssl, result)
#    1935
#
# J:\Code\conda\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1670         else:
# -> 1671             _raise_current_error()
#    1672
#
# J:\Code\conda\lib\site-packages\OpenSSL\_util.py in exception_from_error_queue(exception_type)
#      53
# ---> 54     raise exception_type(errors)
#      55
#
# Error: [('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')]
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# J:\Code\conda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# J:\Code\conda\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#
# J:\Code\conda\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#
# J:\Code\conda\lib\site-packages\urllib3\connection.py in connect(self)
#     359             server_hostname=server_hostname,
# --> 360             ssl_context=context,
#     361         )
#
# J:\Code\conda\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     369         if HAS_SNI and server_hostname is not None:
# --> 370             return context.wrap_socket(sock, server_hostname=server_hostname)
#     371
#
# J:\Code\conda\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     490             except OpenSSL.SSL.Error as e:
# --> 491                 raise ssl.SSLError("bad handshake: %r" % e)
#     492             break
#
# SSLError: ("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# J:\Code\conda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# J:\Code\conda\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# J:\Code\conda\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#
# MaxRetryError: HTTPSConnectionPool(host='www.google.com', port=443): Max retries exceeded with url: /search?q=Grounded%20address (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-15-227ae986c385> in <module>
#       1 i = 0
#       2 for url in url_list:
# ----> 3     getpage= requests.get(url).text
#       4     soup = BeautifulSoup(getpage, 'html.parser')
#       5     if len(soup.findAll("div", {"BNeawe iBp4i AP7Wnd"}))>1:
#
# J:\Code\conda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# J:\Code\conda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# J:\Code\conda\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# J:\Code\conda\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# J:\Code\conda\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='www.google.com', port=443): Max retries exceeded with url: /search?q=Grounded%20address (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))

# %% [markdown]
# ### GET COORDINATES

# %%
members = pd.read_excel("Address.xlsx")
members['COORD']= ""
members.head()
# Out:
#               COMPANIES                           CONTACT  \
# 0              Rerooted                      Danny Dawson
# 1           Think Ocean                  Hugo Valdes-Vera
# 2                  Olio              Saasha Celestial-One
# 3                 Aduna                       Andrew Hunt
# 4  Groots Urban Farming  Carlos Gomez/Alessandro Calcagno
#
#                                EMAIL Telephone                   2nd email  \
# 0          dan@rerootedorganic.co.uk       NaN                         NaN
# 1  Hugovaldes-vera@thinkocean.org.uk       NaN      Info@thinkocean.org.uk
# 2                  saasha@olioex.com       NaN                         NaN
# 3              andrew.hunt@aduna.com       NaN  chandni.sanghani@aduna.com
# 4     alessandro.calcagno@groots.eco       NaN                         NaN
#
#                    Website  TELEPHONE Country Unnamed: 8 MoU Sent  \
# 0    rerootedorganic.co.uk        NaN      UK        NaN       OK
# 1        thinkocean.org.uk        NaN      UK        NaN       OK
# 2           www.olioex.com        NaN      UK        NaN       OK
# 3            www.aduna.com        NaN      UK        NaN       OK
# 4  https://www.groots.eco/        NaN      UK        NaN       OK
#
#   MoU received Logo Logo on Website  \
# 0           OK   OK              OK
# 1          NaN   OK             NaN
# 2           OK   OK             NaN
# 3           OK   OK             NaN
# 4          NaN   OK             NaN
#
#                                              ADDRESS  \
# 0           11 Burke Rd, Totnes TQ9 5XL, Royaume-Uni
# 1                            , London, United Kindom
# 2                            , London, United Kindom
# 3           85 Great Portland Street, London W1W 7LT
# 4  Ronda Indústria, 6, 08210 Barberà del Vallès, ...
#
#                             COORD_sav                         COORD_sav.1  \
# 0            (50.4350583, -3.6821571)            (50.4350583, -3.6821571)
# 1            (51.5073219, -0.1276474)            (51.5073219, -0.1276474)
# 2  (51.5185058, -0.14220490480313072)  (51.5185058, -0.14220490480313072)
# 3  (51.5185058, -0.14220490480313072)  (51.5185058, -0.14220490480313072)
# 4    (60.733592650000006, 24.7768369)    (60.733592650000006, 24.7768369)
#
#   COORD
# 0
# 1
# 2
# 3
# 4

# %%
i=0
from geopy.geocoders import Nominatim
import time
geolocator = Nominatim(user_agent="my_user_agent")
for address in members["ADDRESS"]:
    loc = geolocator.geocode(address)
    print (address)
    if address!= "no address found":
        if loc != None:
            #print("latitude is :-" ,loc.latitude,"\nlongtitude is:-" ,loc.longitude)
            members['COORD'][i]= loc.latitude, loc.longitude
    else:
        members['COORD'][i]= "NA"
    i+=1
# Out:
# 11 Burke Rd, Totnes TQ9 5XL, Royaume-Uni
# J:\Code\conda\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# , London, United Kindom
# , London, United Kindom
# 85 Great Portland Street, London W1W 7LT
# Ronda Indústria, 6, 08210 Barberà del Vallès, Barcelona, Espagne
# Heathrow, United Kingdom
# no address found
# J:\Code\conda\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# Paloheimonkatu 2, 11130 Riihimäki
# Carrer Major de Sarrià, 67, 08017 Barcelona, Espagne
# no address found
# Codebase, 37a Castle Terrace, Edinburgh EH1 2EL
# Dean Park House, 2 Mansfield Rd, Balerno EH14 7LA, Royaume-Uni
# La Sabatarie, 81260 Cambounes
# Allée de Saint-Malo 64C 94569, Rungis
# The Enterprise Centre, University Of East Anglia Resear, Norwich, NR4 7TJ
# ZA Les Bouleaux, 88240 Les Voivres
# 14 St George's Pl, Brighton BN1 4GB, Royaume-Uni
# 100 avenue Harrison 59262 Sainghin-en-Mélantois FRANCE
# no address found
# London
# 25 Lavington St, London SE1 0NZ, Royaume-Uni
# no address found
# no address found
# 51 Tasman, London, United Kingdom, SW9 9LZ
# 160 ROBINSON ROAD, #14-04, Singapore 068914
# Siège social, 10 Allée du Port Maillard, 44000 Nantes
# Reading Bridge House, George Street, Reading, Berkshire, United Kingdom, RG1 8LS
# Dalston, Londres, Royaume-Uni
# 16 Rue de l'Hôtel des Postes, 06000 Nice
# 1 Rue de Montfort, 35000 Rennes
# no address found
# 66, avenue des Champs-Elysées 75008 Paris, France
# no address found
# no address found
# Unit 25, IMEX Business Centre, Bilston Glen Industrial Estate, Loanhead, Edinburgh EH20 9LZ, Royaume-Uni
# 15 Boulevard Diderot, 75012 Paris
# 27 Boulevard Hippolyte Marquès, 94200 Ivry-sur-Seine
# 5 Rue Saint-Pantaléon, 31000 Toulouse
# Lange Haven 132, 3111 CK Schiedam, Pays-Bas
# Darwin Ecosystème, 87 Quai des Queyries Bâtiment 2 33100 Bordeaux
# 234 Rue de la Convention, 75015 Paris
# 3 Rue Poulbot, 75018 Paris
# 1 Rue du Dr Labbé, 75020 Paris
# Ankerkade 141 6222NL Maastricht
# 34 Rue Camille Pelletan, 92300 Levallois-Perret
# 4 Cross St, Beeston, Nottingham NG9 2NX, Royaume-Uni
# 38 College road Epsom KT174HJ UNITED KINGDOM
# 25 Lavington St, London SE1 0NZ, Royaume-Uni
# Witherdens Hall/Popsall La, Canterbury CT3 1AT, Royaume-Uni
# 20-22 Wenlock Road N1 7GU London
# Malaysia
# Dublin, Ireland
# CAN Mezzanine, 7-14 Great Dover St, London SE1 4YR, Royaume-Uni
# Dublin, Ireland
# no address found
# Dublin, Ireland
# 2 Wyndham St N, Guelph, ON N1H 4E3, Canada
# no address found
# Hölderlin Anlage 12, 95447 Bayreuth, Allemagne
# no address found
# no address found
# Shanghai, Jing An
# no address found
# no address found
# no address found
# 18 Hampton Rd, Twickenham TW2 5QB, Royaume-Uni
# no address found
# 15 Allée Paul Langevin, 76230 Bois-Guillaume
# Riverside, 1 Hester Rd, Battersea, London SW11 4AN, Royaume-Uni
# The Warren Potter Row, South Heath, Great Missenden, Buckinghamshire, England, HP16 9LT
# London, United Kingdom
# Business Center Al Shmookh Building UAQ Free Trade Zone United Arab Emirates
# Ireland
# 107 Quai Jean de Béthencourt, 76100 Rouen
# 18-20 London Ln, London E8 3PR, Royaume-Uni
# no address found
# Sausalito, CA US
# no address found
# 11 Avenue Des Capucines, Quatre Bornes, Maurice
# no address found
# St.-Martin-Str. 59 81669 Munich Germany
# Place Chauderon 23, 1003 Lausanne, Suisse
# 39-41 Westow Hill, SE19 1TJ
# Ul. Josipa Prikrila 4, 10110, Zagreb, Croatie
# 1502 Bryant Ave, St Paul, MN 55115, États-Unis
# North Andover, Massachussets
# no address found
# no address found
# 5 Merchant Square London W2 1AY
# Dunnock Way, Oxford OX4 7EX, Royaume-Uni
# no address found
# London
# Santa Monica, CA
# sussex
# Weezenhof 2958, 6536 HN Nijmegen, Pays-Bas
# South Devon House, Babbage Road, Totnes TQ9 5JA
# Konstitucijos pr. 21C, QUADRUM NORTH 08130 Vilnius
# 22 Woodford Avenue, Ilford, United Kingdom, IG2 6XG
# 32, Ddole Enterprise Park, Ddole Road Industrial Estate, Llandrindod Wells, Powys LD1 6DF
# 15a Brunswick Road, Hove, BN3 1DG, UK
# Flexspace Business Centre, Bellshill Industrial Estate, Belgrave Street, Bellshill, ML4 3NP
# San Diego, CA
# Lisbon Portugal

# %%
members.head(20)
# Out:
#                COMPANIES                           CONTACT  \
# 0               Rerooted                      Danny Dawson
# 1            Think Ocean                  Hugo Valdes-Vera
# 2                   Olio              Saasha Celestial-One
# 3                  Aduna                       Andrew Hunt
# 4   Groots Urban Farming  Carlos Gomez/Alessandro Calcagno
# 5             City Farms                    Jonathan Lodge
# 6               Grounded                       Bryn Ferris
# 7                  Ivalo                   Matti Laminsalo
# 8              Sea 2 see            Francois Van den Abele
# 9   Films for the Planet                      Thea La Grou
# 10                  Tula                        Adam Nosal
# 11        Heart in Mouth                      Ishbel Smith
# 12           Dendropolis          Laurie and Mathias Barat
# 13              PandoBac                          Shu Zang
# 14                  Ehab                       Josh Graham
# 15                 In'Bo                 Quentin le Jannou
# 16    School of the Wild                     Nigel Bergman
# 17         Ciel et Terre                    Camille Dejode
# 18            EvoluteSix                       Graham Boyd
# 19               (S)wear                     Lucan Creamer
#
#                                 EMAIL Telephone  \
# 0           dan@rerootedorganic.co.uk       NaN
# 1   Hugovaldes-vera@thinkocean.org.uk       NaN
# 2                   saasha@olioex.com       NaN
# 3               andrew.hunt@aduna.com       NaN
# 4      alessandro.calcagno@groots.eco       NaN
# 5             jgl@cityfarmsystems.com       NaN
# 6                 bryn@grounded.co.uk       NaN
# 7                     matti@ivalo.com       NaN
# 8                    fvda@sea2see.org       NaN
# 9               cynthlagrou@gmail.com       NaN
# 10               adamnosal@icloud.com       NaN
# 11              info@heartinmouth.org       NaN
# 12       laurie.viala@dendropolis.org       NaN
# 13             shu.zhang@pandobac.com       NaN
# 14            joshmccgraham@gmail.com       NaN
# 15                    quentin@inbo.fr       NaN
# 16          nigel@schoolofthewild.com       NaN
# 17            cdejode@cieletterre.net       NaN
# 18              graham@evolutesix.com       NaN
# 19                   lucan@weswear.io       NaN
#
#                         2nd email                            Website  \
# 0                             NaN              rerootedorganic.co.uk
# 1          Info@thinkocean.org.uk                  thinkocean.org.uk
# 2                             NaN                     www.olioex.com
# 3      chandni.sanghani@aduna.com                      www.aduna.com
# 4                             NaN            https://www.groots.eco/
# 5                             NaN  http://www.city-farm-systems.com/
# 6                             NaN            https://grounded.co.uk/
# 7                             NaN                          ivalo.com
# 8                             NaN           https://www.sea2see.org/
# 9                             NaN     https://filmsfortheplanet.com/
# 10                            NaN                      www.tula.town
# 11                            NaN                   heartinmouth.org
# 12  mathias.barat@dendropolis.org        https://en.dendropolis.org/
# 13                            NaN          https://www.pandobac.com/
# 14                            NaN                   https://ehab.co/
# 15                antoine@inbo.fr                https://inbo.fr/fr/
# 16                            NaN   https://www.schoolofthewild.com/
# 17                            NaN  https://www.ciel-et-terre.net/fr/
# 18                            NaN        https://www.evolutesix.com/
# 19                            NaN             https://www.weswear.io
#
#     TELEPHONE Country Unnamed: 8 MoU Sent MoU received Logo Logo on Website  \
# 0         NaN      UK        NaN       OK           OK   OK              OK
# 1         NaN      UK        NaN       OK          NaN   OK             NaN
# 2         NaN      UK        NaN       OK           OK   OK             NaN
# 3         NaN      UK        NaN       OK           OK   OK             NaN
# 4         NaN      UK        NaN       OK          NaN   OK             NaN
# 5         NaN      UK        NaN       OK           OK   OK             NaN
# 6         NaN      UK        NaN       OK           OK   OK             NaN
# 7         NaN      UK        NaN       OK          NaN   OK             NaN
# 8         NaN      UK        NaN       OK          NaN   OK             NaN
# 9         NaN     USA        NaN       OK          NaN   OK             NaN
# 10        NaN      UK        NaN       OK          NaN   OK             NaN
# 11        NaN      UK        NaN       OK          NaN   OK             NaN
# 12        NaN      FR        NaN       OK          NaN   OK             NaN
# 13        NaN      FR        NaN       OK           OK   OK             NaN
# 14        NaN      UK        NaN       OK          NaN   OK             NaN
# 15        NaN      FR        NaN       OK           OK   OK             NaN
# 16        NaN      UK        NaN       OK           OK   OK             NaN
# 17        NaN      FR        NaN       OK           OK   OK             NaN
# 18        NaN      UK        NaN       OK           OK   OK             NaN
# 19        NaN      UK        NaN       OK           OK   OK              OK
#
#                                               Address  \
# 0            11 Burke Rd, Totnes TQ9 5XL, Royaume-Uni
# 1                              London, United Kingdom
# 2                               London, United Kindom
# 3            85 Great Portland Street, London W1W 7LT
# 4   Ronda Indústria, 6, 08210 Barberà del Vallès, ...
# 5                                            Heathrow
# 6                                    no address found
# 7                   Paloheimonkatu 2, 11130 Riihimäki
# 8   Carrer Major de Sarrià, 67, 08017 Barcelona, E...
# 9                                    no address found
# 10    Codebase, 37a Castle Terrace, Edinburgh EH1 2EL
# 11  Dean Park House, 2 Mansfield Rd, Balerno EH14 ...
# 12                      La Sabatarie, 81260 Cambounes
# 13              Allée de Saint-Malo 64C 94569, Rungis
# 14  The Enterprise Centre, University Of East Angl...
# 15                 ZA Les Bouleaux, 88240 Les Voivres
# 16   14 St George's Pl, Brighton BN1 4GB, Royaume-Uni
# 17  100 avenue Harrison 59262 Sainghin-en-Mélantoi...
# 18                                   no address found
# 19                                             London
#
#                                  COORD
# 0             (50.4350583, -3.6821571)
# 1             (51.5073219, -0.1276474)
# 2   (51.5185058, -0.14220490480313072)
# 3   (51.5185058, -0.14220490480313072)
# 4     (60.733592650000006, 24.7768369)
# 5   (51.46773895, -0.4587800741571181)
# 6                                   NA
# 7     (60.733592650000006, 24.7768369)
# 8              (41.3983899, 2.1222578)
# 9                                   NA
# 10            (51.5049496, -0.0999799)
# 11            (51.5461173, -0.0756793)
# 12             (43.6099783, 2.4230128)
# 13            (48.1111851, -1.6813799)
# 14             (48.8709458, 2.3058679)
# 15     (48.0245143, 6.302434142876608)
# 16            (50.8270965, -0.1353659)
# 17             (43.6032267, 1.4439801)
# 18                                  NA
# 19            (51.5073219, -0.1276474)

# %%
members.to_excel(r'Address1.xlsx', index = False)

# %% [markdown]
# ### Generate the map

# %%
members = pd.read_excel("Address.xlsx")

# %%
members = members[['COMPANIES','WEBSITE','ADDRESS','COORD']]
members = members.dropna().reset_index()
members.head(30)
# Out:
#     index                  COMPANIES  \
# 0       0                   Rerooted
# 1       1                Think Ocean
# 2       2                       Olio
# 3       3                      Aduna
# 4       4       Groots Urban Farming
# 5       5                 City Farms
# 6       7                      Ivalo
# 7       8                  Sea 2 see
# 8      10                       Tula
# 9      11             Heart in Mouth
# 10     12                Dendropolis
# 11     13                   PandoBac
# 12     14                       Ehab
# 13     15                      In'Bo
# 14     16         School of the Wild
# 15     17              Ciel et Terre
# 16     19                    (S)wear
# 17     20                   Envsight
# 18     23          Reboot innovation
# 19     24                   DatHappy
# 20     25                 N'Go shoes
# 21     26                   EcoFleet
# 22     27              Mindwalk Yoga
# 23     28                   Bif Kids
# 24     29                      Newcy
# 25     31  Architecture regenerative
# 26     34            Healthy Nibbles
# 27     35                    Bioxegy
# 28     36                   Bluedigo
# 29     37               SCOP Houself
#
#                                        WEBSITE  \
# 0                        rerootedorganic.co.uk
# 1                            thinkocean.org.uk
# 2                               www.olioex.com
# 3                                www.aduna.com
# 4                      https://www.groots.eco/
# 5            http://www.city-farm-systems.com/
# 6                                    ivalo.com
# 7                     https://www.sea2see.org/
# 8                                www.tula.town
# 9                             heartinmouth.org
# 10                 https://en.dendropolis.org/
# 11                   https://www.pandobac.com/
# 12                            https://ehab.co/
# 13                         https://inbo.fr/fr/
# 14            https://www.schoolofthewild.com/
# 15           https://www.ciel-et-terre.net/fr/
# 16                      https://www.weswear.io
# 17                   https://www.envsight.com/
# 18         https://www.rebootinnovation.com/#!
# 19                   https://www.dathappy.com/
# 20                   https://ngo-shoes.com/fr/
# 21                    https://theecofleet.com/
# 22               https://www.mindwalkyoga.org/
# 23                     https://www.bifkids.com
# 24                           https://newcy.fr/
# 25  https://www.architecture-regenerative.com/
# 26            https://www.healthynibbles.co.uk
# 27                    https://www.bioxegy.com/
# 28                        https://bluedigo.fr/
# 29                     http://scop-houself.fr/
#
#                                               ADDRESS  \
# 0            11 Burke Rd, Totnes TQ9 5XL, Royaume-Uni
# 1                             , London, United Kindom
# 2                             , London, United Kindom
# 3            85 Great Portland Street, London W1W 7LT
# 4   Ronda Indústria, 6, 08210 Barberà del Vallès, ...
# 5                            Heathrow, United Kingdom
# 6                   Paloheimonkatu 2, 11130 Riihimäki
# 7   Carrer Major de Sarrià, 67, 08017 Barcelona, E...
# 8     Codebase, 37a Castle Terrace, Edinburgh EH1 2EL
# 9   Dean Park House, 2 Mansfield Rd, Balerno EH14 ...
# 10                      La Sabatarie, 81260 Cambounes
# 11              Allée de Saint-Malo 64C 94569, Rungis
# 12  The Enterprise Centre, University Of East Angl...
# 13                 ZA Les Bouleaux, 88240 Les Voivres
# 14   14 St George's Pl, Brighton BN1 4GB, Royaume-Uni
# 15  100 avenue Harrison 59262 Sainghin-en-Mélantoi...
# 16                                             London
# 17       25 Lavington St, London SE1 0NZ, Royaume-Uni
# 18         51 Tasman, London, United Kingdom, SW9 9LZ
# 19        160 ROBINSON ROAD, #14-04, Singapore 068914
# 20  Siège social, 10 Allée du Port Maillard, 44000...
# 21  Reading Bridge House, George Street, Reading, ...
# 22                      Dalston, Londres, Royaume-Uni
# 23           16 Rue de l'Hôtel des Postes, 06000 Nice
# 24                    1 Rue de Montfort, 35000 Rennes
# 25  66, avenue des Champs-Elysées 75008 Paris, France
# 26  Unit 25, IMEX Business Centre, Bilston Glen In...
# 27                  15 Boulevard Diderot, 75012 Paris
# 28  27 Boulevard Hippolyte Marquès, 94200 Ivry-sur...
# 29              5 Rue Saint-Pantaléon, 31000 Toulouse
#
#                                  COORD
# 0             (50.4350583, -3.6821571)
# 1             (51.5073219, -0.1276474)
# 2   (51.5185058, -0.14220490480313072)
# 3   (51.5185058, -0.14220490480313072)
# 4              (60.733592, 24.7768369)
# 5   (51.46773895, -0.4587800741571181)
# 6              (60.733592, 24.7768369)
# 7              (41.3983899, 2.1222578)
# 8             (51.5049496, -0.0999799)
# 9             (51.5461173, -0.0756793)
# 10             (43.6099783, 2.4230128)
# 11            (48.1111851, -1.6813799)
# 12             (48.8709458, 2.3058679)
# 13             (48.0245143, 6.3024341)
# 14            (50.8270965, -0.1353659)
# 15             (43.6032267, 1.4439801)
# 16            (51.5073219, -0.1276474)
# 17            (51.5049496, -0.0999799)
# 18             (51.5314604, -0.094136)
# 19              (1.354728, 103.866958)
# 20            (53.3497645, -6.2602732)
# 21            (51.49983975, -0.092929)
# 22            (51.5461173, -0.0756793)
# 23             (43.7011549, 7.2743607)
# 24            (48.1111851, -1.6813799)
# 25             (48.8709458, 2.3058679)
# 26            (51.5073219, -0.1276474)
# 27             (48.8457237, 2.3712741)
# 28             (48.8188414, 2.3718712)
# 29             (43.6032267, 1.4439801)

# %%
count = 0; i=0
import folium
import webbrowser
import math
mapObj = folium.Map(location = [16, 0],
                    zoom_start = 3,
                    tiles='Stamen watercolor')
                    #tiles = 'Stamen Toner')

# create marker object for Berlin, one by one for every location in data DataFrame
for coord in members.COORD:
    coord = str(coord)
    coord = str(coord).replace("(","")
    coord = str(coord).replace(")","")
    coord = str(coord).replace(" ","")
    coord = coord.split(",")
    # link to website
    link = "<a href=" + members.WEBSITE[i] + " target=blank>" + members.WEBSITE[i]+ "</a>"
    # Marker object
    markerObj = folium.Marker(location = (coord[0], coord[1]),
                              popup=link,
                              tooltip=members.COMPANIES[i], 
                              color="red", 
                              prefix='fa',
                              icon=folium.Icon(color='yellow', icon="plus-circle", prefix='fa'))
    # add marker to map
    markerObj.add_to(mapObj)
    count+=1
    # display map
    i+=1
mapObj.save('PositiveMembers.html')
mapObj
# Out:
# J:\Code\conda\lib\site-packages\ipykernel_launcher.py:25: UserWarning: color argument of Icon should be one of: {'blue', 'gray', 'red', 'beige', 'lightgray', 'orange', 'lightgreen', 'darkred', 'darkgreen', 'darkpurple', 'lightred', 'cadetblue', 'purple', 'white', 'pink', 'black', 'darkblue', 'green', 'lightblue'}.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Out:
# 81

# %%
help(folium.Map)
# Out:
# Help on class Map in module folium.folium:
#
# class Map(branca.element.MacroElement)
#  |  Map(location=None, width='100%', height='100%', left='0%', top='0%', position='relative', tiles='OpenStreetMap', attr=None, min_zoom=0, max_zoom=18, zoom_start=10, min_lat=-90, max_lat=90, min_lon=-180, max_lon=180, max_bounds=False, crs='EPSG3857', control_scale=False, prefer_canvas=False, no_touch=False, disable_3d=False, png_enabled=False, zoom_control=True, **kwargs)
#  |
#  |  Create a Map with Folium and Leaflet.js
#  |
#  |  Generate a base map of given width and height with either default
#  |  tilesets or a custom tileset URL. The following tilesets are built-in
#  |  to Folium. Pass any of the following to the "tiles" keyword:
#  |
#  |      - "OpenStreetMap"
#  |      - "Mapbox Bright" (Limited levels of zoom for free tiles)
#  |      - "Mapbox Control Room" (Limited levels of zoom for free tiles)
#  |      - "Stamen" (Terrain, Toner, and Watercolor)
#  |      - "Cloudmade" (Must pass API key)
#  |      - "Mapbox" (Must pass API key)
#  |      - "CartoDB" (positron and dark_matter)
#  |
#  |  You can pass a custom tileset to Folium by passing a Leaflet-style
#  |  URL to the tiles parameter: ``http://{s}.yourtiles.com/{z}/{x}/{y}.png``
#  |
#  |  Parameters
#  |  ----------
#  |  location: tuple or list, default None
#  |      Latitude and Longitude of Map (Northing, Easting).
#  |  width: pixel int or percentage string (default: '100%')
#  |      Width of the map.
#  |  height: pixel int or percentage string (default: '100%')
#  |      Height of the map.
#  |  tiles: str, default 'OpenStreetMap'
#  |      Map tileset to use. Can choose from a list of built-in tiles,
#  |      pass a custom URL or pass `None` to create a map without tiles.
#  |      For more advanced tile layer options, use the `TileLayer` class.
#  |  min_zoom: int, default 0
#  |      Minimum allowed zoom level for the tile layer that is created.
#  |  max_zoom: int, default 18
#  |      Maximum allowed zoom level for the tile layer that is created.
#  |  zoom_start: int, default 10
#  |      Initial zoom level for the map.
#  |  attr: string, default None
#  |      Map tile attribution; only required if passing custom tile URL.
#  |  crs : str, default 'EPSG3857'
#  |      Defines coordinate reference systems for projecting geographical points
#  |      into pixel (screen) coordinates and back.
#  |      You can use Leaflet's values :
#  |      * EPSG3857 : The most common CRS for online maps, used by almost all
#  |      free and commercial tile providers. Uses Spherical Mercator projection.
#  |      Set in by default in Map's crs option.
#  |      * EPSG4326 : A common CRS among GIS enthusiasts.
#  |      Uses simple Equirectangular projection.
#  |      * EPSG3395 : Rarely used by some commercial tile providers.
#  |      Uses Elliptical Mercator projection.
#  |      * Simple : A simple CRS that maps longitude and latitude into
#  |      x and y directly. May be used for maps of flat surfaces
#  |      (e.g. game maps). Note that the y axis should still be inverted
#  |      (going from bottom to top).
#  |  control_scale : bool, default False
#  |      Whether to add a control scale on the map.
#  |  prefer_canvas : bool, default False
#  |      Forces Leaflet to use the Canvas back-end (if available) for
#  |      vector layers instead of SVG. This can increase performance
#  |      considerably in some cases (e.g. many thousands of circle
#  |      markers on the map).
#  |  no_touch : bool, default False
#  |      Forces Leaflet to not use touch events even if it detects them.
#  |  disable_3d : bool, default False
#  |      Forces Leaflet to not use hardware-accelerated CSS 3D
#  |      transforms for positioning (which may cause glitches in some
#  |      rare environments) even if they're supported.
#  |  zoom_control : bool, default True
#  |      Display zoom controls on the map.
#  |  **kwargs
#  |      Additional keyword arguments are passed to Leaflets Map class:
#  |      https://leafletjs.com/reference-1.6.0.html#map
#  |
#  |  Returns
#  |  -------
#  |  Folium Map Object
#  |
#  |  Examples
#  |  --------
#  |  >>> m = folium.Map(location=[45.523, -122.675],
#  |  ...                        width=750, height=500)
#  |  >>> m = folium.Map(location=[45.523, -122.675],
#  |                             tiles='Mapbox Control Room')
#  |  >>> m = folium.Map(location=(45.523, -122.675), max_zoom=20,
#  |                             tiles='Cloudmade', API_key='YourKey')
#  |  >>> m = folium.Map(
#  |  ...    location=[45.523, -122.675],
#  |  ...    zoom_start=2,
#  |  ...    tiles='http://{s}.tiles.mapbox.com/v3/mapbox.control-room/{z}/{x}/{y}.png',
#  |  ...    attr='Mapbox attribution'
#  |  ...)
#  |
#  |  Method resolution order:
#  |      Map
#  |      branca.element.MacroElement
#  |      branca.element.Element
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, location=None, width='100%', height='100%', left='0%', top='0%', position='relative', tiles='OpenStreetMap', attr=None, min_zoom=0, max_zoom=18, zoom_start=10, min_lat=-90, max_lat=90, min_lon=-180, max_lon=180, max_bounds=False, crs='EPSG3857', control_scale=False, prefer_canvas=False, no_touch=False, disable_3d=False, png_enabled=False, zoom_control=True, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  choropleth(self, *args, **kwargs)
#  |      Call the Choropleth class with the same arguments.
#  |
#  |      This method may be deleted after a year from now (Nov 2018).
#  |
#  |  fit_bounds(self, bounds, padding_top_left=None, padding_bottom_right=None, padding=None, max_zoom=None)
#  |      Fit the map to contain a bounding box with the
#  |      maximum zoom level possible.
#  |
#  |      Parameters
#  |      ----------
#  |      bounds: list of (latitude, longitude) points
#  |          Bounding box specified as two points [southwest, northeast]
#  |      padding_top_left: (x, y) point, default None
#  |          Padding in the top left corner. Useful if some elements in
#  |          the corner, such as controls, might obscure objects you're zooming
#  |          to.
#  |      padding_bottom_right: (x, y) point, default None
#  |          Padding in the bottom right corner.
#  |      padding: (x, y) point, default None
#  |          Equivalent to setting both top left and bottom right padding to
#  |          the same value.
#  |      max_zoom: int, default None
#  |          Maximum zoom to be used.
#  |
#  |      Examples
#  |      --------
#  |      >>> m.fit_bounds([[52.193636, -2.221575], [52.636878, -1.139759]])
#  |
#  |  keep_in_front(self, *args)
#  |      Pass one or multiple layers that must stay in front.
#  |
#  |      The ordering matters, the last one is put on top.
#  |
#  |      Parameters
#  |      ----------
#  |      *args :
#  |          Variable length argument list. Any folium object that counts as an
#  |          overlay. For example FeatureGroup or TileLayer.
#  |          Does not work with markers, for those use z_index_offset.
#  |
#  |  render(self, **kwargs)
#  |      Renders the HTML representation of the element.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from branca.element.Element:
#  |
#  |  add_child(self, child, name=None, index=None)
#  |      Add a child.
#  |
#  |  add_children(self, child, name=None, index=None)
#  |      Add a child.
#  |
#  |  add_to(self, parent, name=None, index=None)
#  |      Add element to a parent.
#  |
#  |  get_bounds(self)
#  |      Computes the bounds of the object and all it's children
#  |      in the form [[lat_min, lon_min], [lat_max, lon_max]].
#  |
#  |  get_name(self)
#  |      Returns a string representation of the object.
#  |      This string has to be unique and to be a python and
#  |      javascript-compatible
#  |      variable name.
#  |
#  |  get_root(self)
#  |      Returns the root of the elements tree.
#  |
#  |  save(self, outfile, close_file=True, **kwargs)
#  |      Saves an Element into a file.
#  |
#  |      Parameters
#  |      ----------
#  |      outfile : str or file object
#  |          The file (or filename) where you want to output the html.
#  |      close_file : bool, default True
#  |          Whether the file has to be closed after write.
#  |
#  |  to_dict(self, depth=-1, ordered=True, **kwargs)
#  |      Returns a dict representation of the object.
#  |
#  |  to_json(self, depth=-1, **kwargs)
#  |      Returns a JSON representation of the object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from branca.element.Element:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
